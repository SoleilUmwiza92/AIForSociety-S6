# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#import the ML libs
import sklearn
import warnings
from sklearn.cluster import KMeans
from sklearn.metrics import max_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')


print("scikit-learn version:", sklearn.__version__)    
print("pandas version:", pd.__version__)            
print("seaborn version:", sns.__version__)  
print("matplotlib version:", matplotlib.__version__)
# Out:
# scikit-learn version: 1.3.0
# pandas version: 1.5.3
# seaborn version: 0.12.2
# matplotlib version: 3.7.1

# %%
df = pd.read_csv("traindata.csv")

print(df.shape)
# Out:
# (20800, 5)

# %% [markdown]
# ### 📃 Sample the data
#
# Below I am viewing dataset to have an impression of the data. For that I am printing 15 random rows.

# %%
df.sample(15)
# Out:
#           id                                              title  \
# 6175    6175  Self-Driving Tesla Was Involved in Fatal Crash...
# 5613    5613  Veteran’s Memorial Desecrated By Protesters, C...
# 17937  17937  Trump Makes Last-Minute Push To Appeal To Whit...
# 4403    4403                                                NaN
# 8529    8529   Don’t Call Them ‘Mocktails’ - The New York Times
# 10086  10086  London Gets More N.F.L. Games. Too Bad About t...
# 17279  17279  In 9/11 Document, View of a Saudi Effort to Th...
# 5031    5031  The Verdant Food of Iran Entices at Persian Ne...
# 1203    1203  Donald Trump Says Hillary Clinton Will Start W...
# 5443    5443  Stars at Obama’s White House Farewell Bash Par...
# 10042  10042  ICE Raids Shrivel Supply of Day Laborers at Ho...
# 15846  15846  A History of Presidents, Mostly Democrats, Pay...
# 2841    2841  Close to Half of American Adults Infected With...
# 528      528  On ‘Dr. Oz,’ Trump Offers Placebo Transparency...
# 13711  13711  BREAKING: China Has Just Joined Russia, Then N...
#
#                                  author  \
# 6175   Bill Vlasic and Neal E. Boudette
# 5613                  Matthew Bernstein
# 17937                               NaN
# 4403                    pascalmolineaux
# 8529                       Rosie Schaap
# 10086                     Victor Mather
# 17279                     Mark Mazzetti
# 5031                       Samin Nosrat
# 1203                                NaN
# 5443                      Jerome Hudson
# 10042                  Chriss W. Street
# 15846               Jennifer Schuessler
# 2841                   Nicholas Bakalar
# 528                    James Poniewozik
# 13711                      Martin Walsh
#
#                                                     text  label
# 6175   DETROIT  —   The race by automakers and techno...      0
# 5613   \nPosted by Matthew Bernstein | Nov 9, 2016 | ...      1
# 17937  Hillary Clinton Waiting In Wings Of Stage Sinc...      1
# 4403   The way the "Defense Budget" in the USA contin...      1
# 8529   I’m always thrilled when a certain former drin...      0
# 10086  Hey, London! You love American football? Well,...      0
# 17279  WASHINGTON  —   The   document detailing possi...      0
# 5031   Pardis Stitt still remembers the grocery shopp...      0
# 1203   Donald Trump Says Hillary Clinton Will Start W...      1
# 5443   A litany of   celebrities braved   temperature...      0
# 10042  Many Home Depots once featured several dozen d...      0
# 15846  President Donald J. Trump’s admiration for And...      0
# 2841   More than 42 percent of Americans between the ...      0
# 528    On Thursday’s episode of “The Dr. Oz Show,” Do...      0
# 13711  \nPosted by Martin Walsh | Oct 26, 2016 | Nati...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
# Checking dataset
df.head(20)
# Out:
#     id                                              title  \
# 0    0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1    1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2    2                  Why the Truth Might Get You Fired
# 3    3  15 Civilians Killed In Single US Airstrike Hav...
# 4    4  Iranian woman jailed for fictional unpublished...
# 5    5  Jackie Mason: Hollywood Would Love Trump if He...
# 6    6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7    7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8    8  Excerpts From a Draft Script for Donald Trump’...
# 9    9  A Back-Channel Plan for Ukraine and Russia, Co...
# 10  10  Obama’s Organizing for Action Partners with So...
# 11  11  BBC Comedy Sketch "Real Housewives of ISIS" Ca...
# 12  12  Russian Researchers Discover Secret Nazi Milit...
# 13  13  US Officials See No Link Between Trump and Russia
# 14  14  Re: Yes, There Are Paid Government Trolls On S...
# 15  15  In Major League Soccer, Argentines Find a Home...
# 16  16  Wells Fargo Chief Abruptly Steps Down - The Ne...
# 17  17  Anonymous Donor Pays $2.5 Million To Release E...
# 18  18                          FBI Closes In On Hillary!
# 19  19  Chuck Todd: ’BuzzFeed Did Donald Trump a Polit...
#
#                               author  \
# 0                      Darrell Lucus
# 1                    Daniel J. Flynn
# 2                 Consortiumnews.com
# 3                    Jessica Purkiss
# 4                     Howard Portnoy
# 5                    Daniel Nussbaum
# 6                                NaN
# 7                    Alissa J. Rubin
# 8                                NaN
# 9       Megan Twohey and Scott Shane
# 10                       Aaron Klein
# 11                   Chris Tomlinson
# 12                     Amando Flavio
# 13                        Jason Ditz
# 14                      AnotherAnnie
# 15                     Jack Williams
# 16  Michael Corkery and Stacy Cowley
# 17                          Starkman
# 18                           The Doc
# 19                         Jeff Poor
#
#                                                  text  label
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1   Ever get the feeling your life circles the rou...      0
# 2   Why the Truth Might Get You Fired October 29, ...      1
# 3   Videos 15 Civilians Killed In Single US Airstr...      1
# 4   Print \nAn Iranian woman has been sentenced to...      1
# 5   In these trying times, Jackie Mason is the Voi...      0
# 6   Ever wonder how Britain’s most iconic pop pian...      1
# 7   PARIS  —   France chose an idealistic, traditi...      0
# 8   Donald J. Trump is scheduled to make a highly ...      0
# 9   A week before Michael T. Flynn resigned as nat...      0
# 10  Organizing for Action, the activist group that...      0
# 11  The BBC produced spoof on the “Real Housewives...      0
# 12  The mystery surrounding The Third Reich and Na...      1
# 13  Clinton Campaign Demands FBI Affirm Trump's Ru...      1
# 14  Yes, There Are Paid Government Trolls On Socia...      1
# 15  Guillermo Barros Schelotto was not the first A...      0
# 16  The scandal engulfing Wells Fargo toppled its ...      0
# 17  A Caddo Nation tribal leader has just been fre...      1
# 18  FBI Closes In On Hillary! Posted on Home » Hea...      1
# 19  Wednesday after   Donald Trump’s press confere...      0

# %%
# checking labels

df.label.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Analyse the labels distribution
df.label.value_counts()
# Out:
# 1    10413
# 0    10387
# Name: label, dtype: int64

# %%
import tensorflow as tf
from transformers import XLNetTokenizer, TFXLNetModel

# Choose the variant of XLNet you want to use
model_name = "xlnet-base-cased"  # For example, "xlnet-base-cased" or "xlnet-large-cased"

# Load XLNet tokenizer and model
tokenizer = XLNetTokenizer.from_pretrained(model_name)
graph = tf.compat.v1.get_default_graph()
with graph.as_default():
    model = TFXLNetModel.from_pretrained(model_name)
# Out:
# WARNING:tensorflow:From C:\Users\csten\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\csten\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\csten\AppData\Local\Temp\ipykernel_5040\2080901288.py:9: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 11
#       9 graph = tf.compat.v1.get_default_graph()
#      10 with graph.as_default():
# ---> 11     model = TFXLNetModel.from_pretrained(model_name)
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py:269, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     265 if from_pt:
#     266     # Load from a PyTorch checkpoint
#     267     return load_pytorch_checkpoint_in_tf2_model(model, resolved_archive_file)
# --> 269 ret = model(model.dummy_inputs, training=False)  # build the network with dummy inputs
#     271 assert os.path.isfile(resolved_archive_file), "Error retrieving file {}".format(resolved_archive_file)
#     272 # 'by_name' allow us to do transfer learning by skipping/adding layers
#     273 # see https://github.com/tensorflow/tensorflow/blob/00fad90125b18b80fe054de1055770cfb8fe4ba3/tensorflow/python/keras/engine/network.py#L1339-L1357
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_xlnet.py:804, in TFXLNetModel.call(self, inputs, **kwargs)
#     803 def call(self, inputs, **kwargs):
# --> 804     outputs = self.transformer(inputs, **kwargs)
#     805     return outputs
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_xlnet.py:515, in TFXLNetMainLayer.call(self, inputs, attention_mask, mems, perm_mask, target_mapping, token_type_ids, input_mask, head_mask, training)
#     509     input_ids = inputs
#     511 # the original code for XLNet uses shapes [len, bsz] with the batch dimension at the end
#     512 # but we want a unified interface in the library with the batch size on the first dimension
#     513 # so we move here the first dimension (batch) to the end
# --> 515 input_ids = tf.transpose(input_ids, perm=(1, 0))
#     516 token_type_ids = tf.transpose(token_type_ids, perm=(1, 0)) if token_type_ids is not None else None
#     517 input_mask = tf.transpose(input_mask, perm=(1, 0)) if input_mask is not None else None
#
# RuntimeError: x: Attempting to capture an EagerTensor without building a function.

# %%
max_len  = 64

full_input_ids = []
full_input_masks = []
full_segment_ids = []

SEG_ID_A   = 0
SEG_ID_B   = 1
SEG_ID_CLS = 2
SEG_ID_SEP = 3
SEG_ID_PAD = 4

UNK_ID = tokenizer.encode("<unk>")[0]
CLS_ID = tokenizer.encode("<cls>")[0]
SEP_ID = tokenizer.encode("<sep>")[0]
MASK_ID = tokenizer.encode("<mask>")[0]
EOD_ID = tokenizer.encode("<eod>")[0]

for i,sentence in enumerate(sentences):
    # Tokenize sentence to token id list
    tokens_a = tokenizer.encode(sentence)
    
    # Trim the len of text
    if(len(tokens_a)>max_len-2):
        tokens_a = tokens_a[:max_len-2]
        
        
    tokens = []
    segment_ids = []
    
    for token in tokens_a:
        tokens.append(token)
        segment_ids.append(SEG_ID_A)
        
    # Add <sep> token 
    tokens.append(SEP_ID)
    segment_ids.append(SEG_ID_A)
    
    
    # Add <cls> token
    tokens.append(CLS_ID)
    segment_ids.append(SEG_ID_CLS)
    
    input_ids = tokens
    
    # The mask has 0 for real tokens and 1 for padding tokens. Only real
    # tokens are attended to.
    input_mask = [0] * len(input_ids)

    # Zero-pad up to the sequence length at fornt
    if len(input_ids) < max_len:
        delta_len = max_len - len(input_ids)
        input_ids = [0] * delta_len + input_ids
        input_mask = [1] * delta_len + input_mask
        segment_ids = [SEG_ID_PAD] * delta_len + segment_ids

    assert len(input_ids) == max_len
    assert len(input_mask) == max_len
    assert len(segment_ids) == max_len
    
    full_input_ids.append(input_ids)
    full_input_masks.append(input_mask)
    full_segment_ids.append(segment_ids)
    
    if 3 > i:
        print("No.:%d"%(i))
        print("sentence: %s"%(sentence))
        print("input_ids:%s"%(input_ids))
        print("attention_masks:%s"%(input_mask))
        print("segment_ids:%s"%(segment_ids))
        print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 19
#      16 MASK_ID = tokenizer.encode("<mask>")[0]
#      17 EOD_ID = tokenizer.encode("<eod>")[0]
# ---> 19 for i,sentence in enumerate(sentences):
#      20     # Tokenize sentence to token id list
#      21     tokens_a = tokenizer.encode(sentence)
#      23     # Trim the len of text
#
# NameError: name 'sentences' is not defined

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\csten\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\csten\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: boto3 in c:\users\csten\anaconda3\lib\site-packages (from transformers) (1.24.28)
# Requirement already satisfied: requests in c:\users\csten\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\csten\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\csten\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: sentencepiece in c:\users\csten\anaconda3\lib\site-packages (from transformers) (0.2.0)
# Requirement already satisfied: sacremoses in c:\users\csten\anaconda3\lib\site-packages (from transformers) (0.0.43)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\csten\anaconda3\lib\site-packages (from boto3->transformers) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\csten\anaconda3\lib\site-packages (from boto3->transformers) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\csten\anaconda3\lib\site-packages (from boto3->transformers) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\csten\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\csten\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\csten\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\csten\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: six in c:\users\csten\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\csten\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: joblib in c:\users\csten\anaconda3\lib\site-packages (from sacremoses->transformers) (1.2.0)
# Requirement already satisfied: colorama in c:\users\csten\anaconda3\lib\site-packages (from tqdm->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\csten\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3->transformers) (2.8.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import XLNetTokenizer, XLNetForSequenceClassification

# Step 2: Download Pretrained XLNet Model
model_name = "xlnet-base-cased"
tokenizer = XLNetTokenizer.from_pretrained(model_name)
model = XLNetForSequenceClassification.from_pretrained(model_name)

# Step 4: Tokenization
input_text = "Your input text here."
tokenized_input = tokenizer(input_text, return_tensors="pt")

# Step 5: Model Inference
with torch.no_grad():
    outputs = model(**tokenized_input)

# Step 6: Post-processing
predictions = torch.softmax(outputs.logits, dim=1)

# Output probabilities for each class
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import torch
#       2 from transformers import XLNetTokenizer, XLNetForSequenceClassification
#       4 # Step 2: Download Pretrained XLNet Model
#
# ModuleNotFoundError: No module named 'torch'
