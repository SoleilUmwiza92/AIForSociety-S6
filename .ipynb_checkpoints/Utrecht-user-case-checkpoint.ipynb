# %% [markdown]
# ## This notebook is for predicting reatail price houses in Utrecht

# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#import the ML libs
import sklearn
from sklearn.metrics import max_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


print("scikit-learn version:", sklearn.__version__)    
print("pandas version:", pd.__version__)            
print("seaborn version:", sns.__version__)  
print("matplotlib version:", matplotlib.__version__)
# Out:
# scikit-learn version: 1.3.0
# pandas version: 1.5.3
# seaborn version: 0.12.2
# matplotlib version: 3.7.1

# %% [markdown]
# ## Load data from .csv(comma separated value file)

# %%
df = pd.read_csv("utrechthousinghuge.csv")

# %%
df.sample(10)
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 1781  902629     3525     11.1       11.0     122.1      247.50         11.0
# 1571  801979     3800     18.6       10.8     200.9      145.80        103.7
# 1047  572749     3500     17.2        9.3     160.0      209.25         48.4
# 1335  691345     3800     17.0        8.0     136.0      144.00         48.0
# 1077  583775     3500     18.7        7.5     140.3      135.00         57.8
# 1247  653123     3500     16.2        8.1     131.2      109.35         34.0
# 1491  761656     3528     12.6       10.0     126.0      225.00         10.0
# 1108  600829     3528     11.2        6.6      73.9      118.80          6.6
# 344   252078     3525     13.5        8.5     114.8      153.00         21.3
# 526   341122     3800     16.0        5.8      92.8      130.50         23.2
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# ...

# %%
df.head()
# Out:
#        id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 0  100426     3528     11.1        5.0      55.5      112.50         10.5
# 1  100871     3528     13.6        5.0      68.0      112.50          8.0
# 2  100936     3800     16.6        6.7     111.2      150.75         44.2
# 3  100970     3800     18.6        6.0     111.6      108.00         39.6
# 4  101191     3800     19.6        6.0     117.6      108.00         45.6
#
#    balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# 0        2    2112    5113       1932          1    494000       670000
# 1        0    2355    5218       1945          1    504000       675000
# 2        2    2656    5200       1946          1    692000       869000
# 3        2    2856    5201       1946          1    521000       628000
# 4        1    2962    5266       1950          1    526000       610000
#
#    energy-eff  monument
# 0           0         1
# 1           0         1
# ...

# %%
# order buildyear
df.sort_values("buildyear").head(10)
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 1482  760128     3800     16.1        7.0     112.7      157.50         28.7
# 474   320123     3800     16.1        6.4     103.0      144.00         39.0
# 1078  590119     3800     15.5        5.8      89.9      130.50         31.9
# 539   350089     3528     14.1        5.0      70.5       90.00         10.5
# 1330  690192     3800     19.5        5.4     105.3       97.20         45.9
# 303   240068     3528     13.2        5.7      75.2      128.25         23.9
# 1834  930065     3528     13.0        5.1      66.3       68.85         20.4
# 22    110095     3528     14.5        6.6      95.7      148.50         29.7
# 1702  870091     3528     14.6        5.3      77.4       71.55         13.8
# 849   490022     3528     11.1        5.2      57.7      117.00         10.9
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# ...

# %%
df.sort_values("buildyear", ascending= False).head(10)
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 1620  823820     3525     11.0        6.7      73.7      120.60          6.7
# 1884  943832     3525     11.6        8.2      95.1      147.60          8.2
# 1525  773859     3525     12.6        8.4     105.8      113.40         30.2
# 1440  733849     3525     12.2        7.3      89.1       98.55          7.3
# 559   353981     3500     19.2        6.5     124.8       87.75         59.8
# 666   403969     3500     18.1        8.5     153.9      191.25         60.4
# 631   383896     3525     14.5        6.5      94.3      146.25         35.8
# 1556  793809     3525     10.1        7.9      79.8      106.65          7.9
# 820   473812     3525     10.7        6.8      72.8       91.80          6.8
# 1640  833999     3500     19.5        8.2     159.9      184.50         77.9
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2000 non-null   int64
#  1   zipcode      2000 non-null   int64
#  2   lot-len      2000 non-null   float64
#  3   lot-width    2000 non-null   float64
#  4   lot-area     2000 non-null   float64
#  5   house-area   2000 non-null   float64
#  6   garden-size  2000 non-null   float64
#  7   balcony      2000 non-null   int64
#  8   x-coor       2000 non-null   int64
#  9   y-coor       2000 non-null   int64
#  10  buildyear    2000 non-null   int64
#  11  bathrooms    2000 non-null   int64
#  12  taxvalue     2000 non-null   int64
#  13  retailvalue  2000 non-null   int64
#  14  energy-eff   2000 non-null   int64
#  15  monument     2000 non-null   int64
# dtypes: float64(5), int64(11)
# memory usage: 250.1 KB

# %%
df.isnull().sum()
# Out:
# id             0
# zipcode        0
# lot-len        0
# lot-width      0
# lot-area       0
# house-area     0
# garden-size    0
# balcony        0
# x-coor         0
# y-coor         0
# buildyear      0
# bathrooms      0
# taxvalue       0
# retailvalue    0
# energy-eff     0
# monument       0
# dtype: int64

# %%
df.describe()
# Out:
#                   id      zipcode      lot-len   lot-width     lot-area  \
# count    2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   550159.413500  3609.088000    14.848500     7.75520   115.236600
# std    257599.198061   131.206058     2.883188     1.69576    34.370459
# min    100426.000000  3500.000000    10.000000     5.00000    50.500000
# 25%    330326.250000  3525.000000    12.425000     6.47500    89.100000
# 50%    556845.500000  3528.000000    14.850000     7.65000   109.950000
# 75%    763794.250000  3800.000000    17.275000     9.10000   138.325000
# max    993963.000000  3800.000000    19.700000    11.00000   215.600000
#
#         house-area  garden-size      balcony       x-coor       y-coor  \
# count  2000.000000   2000.00000  2000.000000  2000.000000  2000.000000
# mean    139.884750     35.45365     1.152500  2484.360500  5484.435000
# std      41.745307     23.86576     0.698203   288.399892   288.538538
# ...

# %% [markdown]
# ## EDA: Exploratory Data Analysis

# %%
plt.hist = df.hist(column="buildyear")
